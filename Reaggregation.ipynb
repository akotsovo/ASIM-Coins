# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import time
import san

# %%
data = pd.read_csv('clean/santiment_final_data.csv')

# %%
data['datetime'] = pd.to_datetime(data['datetime'])

data['date'] = data['datetime'].dt.date

data = data.set_index('date')

data = data.drop(columns=["Unnamed: 0", "datetime"])

# %%
data
# Out:
#             bitcoin_volumes  ethereum_volumes  tether_volumes  ripple_volumes  \
# date
# 2021-07-28     3.870240e+10      1.899130e+10    6.421117e+10    6.452961e+09
# 2021-07-29     2.716715e+10      1.631337e+10    4.991068e+10    3.717955e+09
# 2021-07-30     3.307278e+10      2.021285e+10    5.852503e+10    3.328524e+09
# 2021-07-31     2.580285e+10      1.800171e+10    5.139467e+10    2.612372e+09
# 2021-08-01     2.668844e+10      2.269799e+10    5.609537e+10    2.529023e+09
# ...                     ...               ...             ...             ...
# 2022-06-21     2.897021e+10      1.563209e+10    5.016586e+10    1.247582e+09
# 2022-06-22     2.857479e+10      1.501059e+10    4.613003e+10    1.064145e+09
# 2022-06-23     2.618810e+10      1.465786e+10    4.319854e+10    9.273246e+08
# 2022-06-26     1.802717e+10      1.209661e+10    3.722868e+10    7.895143e+08
# 2022-06-27     2.096570e+10      1.249223e+10    3.929695e+10    9.895719e+08
#
#             solana_volumes  cardano_volumes  avalanche_volumes  \
# date
# 2021-07-28    3.156826e+08     1.793329e+09         68268675.0
# 2021-07-29    4.480096e+08     1.466955e+09         66712426.0
# 2021-07-30    6.178302e+08     1.556740e+09         71146688.0
# 2021-07-31    5.871682e+08     1.312377e+09         67970748.0
# 2021-08-01    4.906399e+08     1.863009e+09         90946247.0
# ...                    ...              ...                ...
# 2022-06-21    1.790090e+09     1.018828e+09        496486132.0
# 2022-06-22    1.533123e+09     8.189774e+08        417581511.0
# 2022-06-23    1.666479e+09     7.115548e+08        482575281.0
# 2022-06-26    1.138725e+09     8.425289e+08        413767908.0
# 2022-06-27    1.253390e+09     7.099926e+08        433026594.0
#
#             stellar_volumes  monero_volumes  bitcoin_prices  ...  \
# date                                                         ...
# 2021-07-28      693920024.0     212216608.0    39995.906469  ...
# 2021-07-29      449501855.0     189494044.0    40008.420847  ...
# 2021-07-30      544526611.0     203635494.0    42235.547709  ...
# 2021-07-31      542423429.0     208721836.0    41626.195676  ...
# 2021-08-01      629418983.0     196766251.0    39974.896026  ...
# ...                     ...             ...             ...  ...
# 2022-06-21      181843171.0      96177268.0    20710.597102  ...
# 2022-06-22      167247661.0      70776491.0    19987.029049  ...
# 2022-06-23      161075206.0      65743632.0    21085.877161  ...
# 2022-06-26      131745823.0      73740343.0    21027.295309  ...
# 2022-06-27      144574714.0      82580078.0    20735.477947  ...
#
#             git_activity_solana  git_activity_cardano  git_activity_avalanche  \
# date
# 2021-07-28                276.0                 836.0                    74.0
# 2021-07-29                489.0                 856.0                    75.0
# 2021-07-30                334.0                 696.0                    49.0
# 2021-07-31                137.0                 162.0                    35.0
# 2021-08-01                 46.0                 137.0                     7.0
# ...                         ...                   ...                     ...
# 2022-06-21                415.0                 636.0                    88.0
# 2022-06-22                534.0                 637.0                    63.0
# 2022-06-23                323.0                 563.0                    69.0
# 2022-06-26                 66.0                  90.0                    16.0
# 2022-06-27                394.0                 475.0                   104.0
#
#             git_activity_stellar  git_activity_monero  circulation_1d_bitcoin  \
# date
# 2021-07-28                 140.0                 40.0           233366.540320
# 2021-07-29                 240.0                 40.0           272288.800730
# 2021-07-30                 182.0                 23.0           140693.679583
# 2021-07-31                  36.0                 36.0            69683.508980
# 2021-08-01                  13.0                 23.0            80602.011178
# ...                          ...                  ...                     ...
# 2022-06-21                 169.0                 17.0           234767.266773
# 2022-06-22                 208.0                 19.0           238833.596679
# 2022-06-23                 261.0                 29.0           187976.537412
# 2022-06-26                   2.0                 19.0            98861.383687
# 2022-06-27                 190.0                 37.0           207523.732736
#
#             circulation_1d_ethereum  circulation_1d_tether  \
# date
# 2021-07-28             9.395430e+05           1.790458e+09
# 2021-07-29             1.082935e+06           1.845509e+09
# 2021-07-30             1.022270e+06           1.712227e+09
# 2021-07-31             1.001426e+06           1.341413e+09
# 2021-08-01             6.666681e+05           1.240329e+09
# ...                             ...                    ...
# 2022-06-21             9.548745e+05           1.532409e+09
# 2022-06-22             1.017342e+06           1.785544e+09
# 2022-06-23             1.238218e+06           1.234796e+09
# 2022-06-26             4.393776e+05           4.993998e+08
# 2022-06-27             9.433080e+05           1.331249e+09
#
#             circulation_1d_ripple  circulation_1d_cardano
# date
# 2021-07-28           4.552209e+08            8.984839e+08
# 2021-07-29           2.547360e+08            4.513222e+08
# 2021-07-30           3.906714e+08            7.397231e+08
# 2021-07-31           1.586135e+08            3.646393e+08
# 2021-08-01           1.323565e+09            3.901627e+08
# ...                           ...                     ...
# 2022-06-21           4.929632e+08            7.325194e+08
# 2022-06-22           3.908619e+08            6.471346e+08
# 2022-06-23           4.807504e+08            5.949355e+08
# 2022-06-26           1.754350e+08            3.721631e+08
# 2022-06-27           7.104985e+08            4.375237e+08
#
# [333 rows x 418 columns]

# %%
coin_list = ["bitcoin", "ethereum", "tether", "ripple", "solana", "luna", "cardano", "avalanche", "stellar", "monero"]

# %%
bitcoin = pd.DataFrame(columns=["a"])
ethereum = pd.DataFrame(columns=["a"])
tether = pd.DataFrame(columns=["a"])
ripple = pd.DataFrame(columns=["a"])
solana = pd.DataFrame(columns=["a"])
luna = pd.DataFrame(columns=["a"])
cardano = pd.DataFrame(columns=["a"])
avalanche = pd.DataFrame(columns=["a"])
stellar = pd.DataFrame(columns=["a"])
monero = pd.DataFrame(columns=["a"])

# %%
for k in coin_list:
    for i in data:
        if k in i:
            print(k)
# Out:
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# bitcoin
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# ethereum
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# tether
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# ripple
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# solana
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# luna
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# cardano
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# avalanche
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# stellar
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero
# monero

# %%
name = "bitcoin"

for i in data:
    if name in i:
        bitcoin[i] = data[i]

# %%
name = "bitcointalk"

for i in bitcoin:
    if name in i:
        bitcoin = bitcoin.drop(columns=i)

# %%
bitcoin = bitcoin.drop(columns="a")

# %%
name = "ethereum"

for i in data:
    if name in i:
        ethereum[i] = data[i]

# %%
name = "bitcointalk"

for i in ethereum:
    if name in i:
        ethereum = ethereum.drop(columns=i)

# %%
ethereum = ethereum.drop(columns="a")

# %%
name = "tether"

for i in data:
    if name in i:
        tether[i] = data[i]

name = "bitcointalk"

for i in tether:
    if name in i:
        tether = tether.drop(columns=i)

tether = tether.drop(columns="a")

# %%
name = "ripple"

for i in data:
    if name in i:
        ripple[i] = data[i]

name = "bitcointalk"

for i in ripple:
    if name in i:
        ripple = ripple.drop(columns=i)

ripple = ripple.drop(columns="a")

# %%
name = "solana"

for i in data:
    if name in i:
        solana[i] = data[i]

name = "bitcointalk"

for i in solana:
    if name in i:
        solana = solana.drop(columns=i)
        
solana = solana.drop(columns="a")

# %%
name = "luna"

for i in data:
    if name in i:
        luna[i] = data[i]

name = "bitcointalk"

for i in luna:
    if name in i:
        luna = luna.drop(columns=i)

luna = luna.drop(columns="a")

# %%
name = "cardano"

for i in data:
    if name in i:
        cardano[i] = data[i]

name = "bitcointalk"

for i in cardano:
    if name in i:
        cardano = cardano.drop(columns=i)

cardano = cardano.drop(columns="a")

# %%
name = "avalanche"

for i in data:
    if name in i:
        avalanche[i] = data[i]

name = "bitcointalk"

for i in avalanche:
    if name in i:
        avalanche = avalanche.drop(columns=i)

avalanche = avalanche.drop(columns="a")

# %%
name = "stellar"

for i in data:
    if name in i:
        stellar[i] = data[i]

name = "bitcointalk"

for i in stellar:
    if name in i:
        stelalr = stellar.drop(columns=i)

stellar = stellar.drop(columns="a")

# %%
name = "monero"

for i in data:
    if name in i:
        monero[i] = data[i]

name = "bitcointalk"

for i in tether:
    if name in i:
        monero = monero.drop(columns=i)

monero = monero.drop(columns="a")

# %%
bitcoin.to_csv('clean/coins/bitcoin_quant.csv')
ethereum.to_csv('clean/coins/ethereum_quant.csv')
tether.to_csv('clean/coins/tether_quant.csv')
ripple.to_csv('clean/coins/ripple_quant.csv')
solana.to_csv('clean/coins/solana_quant.csv')
luna.to_csv('clean/coins/luna_quant.csv')
cardano.to_csv('clean/coins/cardano_quant.csv')
avalanche.to_csv('clean/coins/avalanche_quant.csv')
stellar.to_csv('clean/coins/stellar_quant.csv')
monero.to_csv('clean/coins/monero_quant.csv')
